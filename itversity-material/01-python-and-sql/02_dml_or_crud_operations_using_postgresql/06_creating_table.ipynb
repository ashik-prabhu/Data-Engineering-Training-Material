# %% [markdown]
# ## Creating Table
#
# Before getting into action with respect to basic DML and queries or CRUD operations, we need to prepare tables.At this time we have not covered DDL yet. All database operations related to managing tables come under DDL.
#
# For now, let's just create the table by copy pasting below `CREATE TABLE` statement. We will get into concepts as part of the subsequent sections.
#
# * Connect to the database.
# * Create the table.

# %% [markdown]
# ## Practice

# %%
# !whoami
# Out:
# itv002461

# %%
# %load_ext sql

# %%
# %env DATABASE_URL=postgresql://itv002461_sms_user:7ji8g7gg8p8olbqbna5vz1tjyikaixco@pg.itversity.com:5433/itv002461_sms_db
# Out:
# env: DATABASE_URL=postgresql://itv002461_sms_user:7ji8g7gg8p8olbqbna5vz1tjyikaixco@pg.itversity.com:5433/itv002461_sms_db

# %%
# %%sql
#
# SELECT * FROM information_schema.tables
# WHERE table_catalog='itv002461_sms_db' AND table_schema='public'
# LIMIT 10
# Out:
# 10 rows affected.
# [('itv002461_sms_db', 'public', 'users_range_part_201609', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('itv002461_sms_db', 'public', 'users_range_part', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('itv002461_sms_db', 'public', 'users_range_part_201605', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('itv002461_sms_db', 'public', 'users_range_part_201606', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('itv002461_sms_db', 'public', 'users_range_part_201607', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('itv002461_sms_db', 'public', 'users_range_part_201608', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('itv002461_sms_db', 'public', 'users_range_part_201610', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('itv002461_sms_db', 'public', 'users_hash_part_4_of_8', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('itv002461_sms_db', 'public', 'users_hash_part_5_of_8', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('itv002461_sms_db', 'public', 'users_hash_part_6_of_8', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)]

# %%
# %%sql
#
# DROP TABLE IF EXISTS users;
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# Done.
# []

# %%
# %%sql
#
# CREATE TABLE users (
#     user_id SERIAL PRIMARY KEY,
#     user_first_name VARCHAR(30) NOT NULL,
#     user_last_name VARCHAR(30) NOT NULL,
#     user_email_id VARCHAR(50) NOT NULL,
#     user_email_validated BOOLEAN DEFAULT FALSE,
#     user_password VARCHAR(200),
#     user_role VARCHAR(1) NOT NULL DEFAULT 'U', --U and A
#     is_active BOOLEAN DEFAULT FALSE,
#     create_ts TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#     last_updated_ts TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# )
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# Done.
# []

# %%
# %%sql
#
# SELECT * FROM information_schema.columns
# WHERE table_name = 'users'
# LIMIT 10
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 10 rows affected.
# [('itv002461_sms_db', 'public', 'users', 'user_id', 1, "nextval('users_user_id_seq'::regclass)", 'NO', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'int4', None, None, None, None, '1', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'user_first_name', 2, None, 'NO', 'character varying', 30, 120, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '2', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'user_last_name', 3, None, 'NO', 'character varying', 30, 120, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '3', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'user_email_id', 4, None, 'NO', 'character varying', 50, 200, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '4', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'user_email_validated', 5, 'false', 'YES', 'boolean', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'bool', None, None, None, None, '5', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'user_password', 6, None, 'YES', 'character varying', 200, 800, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '6', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'user_role', 7, "'U'::character varying", 'NO', 'character varying', 1, 4, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '7', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'is_active', 8, 'false', 'YES', 'boolean', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'bool', None, None, None, None, '8', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'create_ts', 9, 'CURRENT_TIMESTAMP', 'YES', 'timestamp without time zone', None, None, None, None, None, 6, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'timestamp', None, None, None, None, '9', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'last_updated_ts', 10, 'CURRENT_TIMESTAMP', 'YES', 'timestamp without time zone', None, None, None, None, None, 6, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'timestamp', None, None, None, None, '10', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES')]

# %%
# %sql SELECT * FROM users;
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 0 rows affected.
# []

# %% [markdown]
# ## Actual Code

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %env DATABASE_URL=postgresql://itv002461_sms_user:7ji8g7gg8p8olbqbna5vz1tjyikaixco@pg.itversity.com:5433/itv002461_sms_db
# Out:
# env: DATABASE_URL=postgresql://itv002461_sms_user:7ji8g7gg8p8olbqbna5vz1tjyikaixco@pg.itversity.com:5433/itv002461_sms_db

# %%
# %%sql
#
# SELECT * FROM information_schema.tables
# WHERE table_catalog = 'itversity_sms_db' AND table_schema = 'public'
# LIMIT 10
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 0 rows affected.
# []

# %%
# %%sql
#
# DROP TABLE IF EXISTS users;
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# Done.
# []

# %%
# %%sql
#
# SELECT * FROM information_schema.tables
# WHERE table_catalog='itv002461_sms_db' AND table_schema='public'
# LIMIT 10
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 0 rows affected.
# []

# %%
# %%sql
#
# CREATE TABLE users (
#     user_id SERIAL PRIMARY KEY,
#     user_first_name VARCHAR(30) NOT NULL,
#     user_last_name VARCHAR(30) NOT NULL,
#     user_email_id VARCHAR(50) NOT NULL,
#     user_email_validated BOOLEAN DEFAULT FALSE,
#     user_password VARCHAR(200),
#     user_role VARCHAR(1) NOT NULL DEFAULT 'U', --U and A
#     is_active BOOLEAN DEFAULT FALSE,
#     create_ts TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
#     last_updated_ts TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# )
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# Done.
# []

# %% [markdown]
# * Let us validate the objects that are created in the underlying database. We can either run query against **information_schema** or use Database Explorer in **SQL Workbench** or even `psql`.

# %%
# %%sql
#
# SELECT * FROM information_schema.tables
# WHERE table_catalog = 'itversity_sms_db' AND table_schema = 'public'
# LIMIT 10
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 0 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM information_schema.columns
# WHERE table_name = 'users'
# LIMIT 10
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 10 rows affected.
# [('itv002461_sms_db', 'public', 'users', 'user_id', 1, "nextval('users_user_id_seq'::regclass)", 'NO', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'int4', None, None, None, None, '1', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'user_first_name', 2, None, 'NO', 'character varying', 30, 120, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '2', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'user_last_name', 3, None, 'NO', 'character varying', 30, 120, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '3', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'user_email_id', 4, None, 'NO', 'character varying', 50, 200, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '4', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'user_email_validated', 5, 'false', 'YES', 'boolean', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'bool', None, None, None, None, '5', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'user_password', 6, None, 'YES', 'character varying', 200, 800, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '6', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'user_role', 7, "'U'::character varying", 'NO', 'character varying', 1, 4, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '7', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'is_active', 8, 'false', 'YES', 'boolean', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'bool', None, None, None, None, '8', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'create_ts', 9, 'CURRENT_TIMESTAMP', 'YES', 'timestamp without time zone', None, None, None, None, None, 6, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'timestamp', None, None, None, None, '9', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'users', 'last_updated_ts', 10, 'CURRENT_TIMESTAMP', 'YES', 'timestamp without time zone', None, None, None, None, None, 6, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'timestamp', None, None, None, None, '10', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES')]

# %%
# %sql SELECT * FROM users
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 0 rows affected.
# []
