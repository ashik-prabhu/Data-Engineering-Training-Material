# %% [markdown]
# ## REST Payload to DB Table
#
# Let us perform an exercise to get the REST Payload into a database table.
# * REST API URL: https://gbfs.citibikenyc.com/gbfs/en/station_information.json
# * Database Name: **{username}_sms_db**
# * First Table Name: **stations**
# * Create table for following fields. Make sure to use appropriate data types
#   * id - Sequence generated primary key
#   * station_id - Uniqueness needs to be enforced.
#   * station_type
#   * name
#   * short_name
#   * capacity
#   * external_id
#   * has_kiosk
#   * legacy_id
#   * region_id
#   * electric_bike_surcharge_waiver
#   * eightd_station_services
# * Get the data from the REST payload into the table **stations** created.
# * Run queries for following scenarios.
#   * Get distinct station types.
#   * Get number of stations per region_id.
#   * Get top 10 stations by capacity.
#   * Get number of stations where there are no kiosks.
# * Second Table Name: **station_rental_types**
# * Create table with following fields
#   * station_id
#   * rental_type - the source field is of type list. The target column in the table should be of type VARCHAR.
#   * station_rental_type_id - sequence generated primary key.
#   * Combination of station_id and rental_type is supposed to be unique.
# * For all station ids where there is one or more rental_types, the data should be inserted into the table separately with rental_type.
# * Sample input record `{'station_id': 1, 'rental_types': ['KEY', 'CREDIT CARD]}`
# * Sample data in the table
#
# |station_id|rental_type|
# |---|---|
# |1|KEY|
# |1|CREDIT CARD|
#
# * Run queries for following scenarios.
#   * Get number of records from **station_rental_types**
#   * Get number of stations where rental_type is **KEY**
#   * Get number of stations where rental_type is **CREDIT CARD**
#   * Get number stations by rental_type.
#   * Get the stations where there is no rental type.

# %% [markdown]
# ## Create Table stations in sms_db

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %env DATABASE_URL=postgresql://itv002461_sms_user:7ji8g7gg8p8olbqbna5vz1tjyikaixco@pg.itversity.com:5433/itv002461_sms_db
# Out:
# env: DATABASE_URL=postgresql://itv002461_sms_user:7ji8g7gg8p8olbqbna5vz1tjyikaixco@pg.itversity.com:5433/itv002461_sms_db

# %%
# %%sql
# CREATE TABLE stations(
#     id SERIAL PRIMARY KEY,
#     station_id VARCHAR(10) NOT NULL,
#     station_type VARCHAR(20) NOT NULL,
#     name VARCHAR(20) NOT NULL,
#     short_name VARCHAR(10) NOT NULL,
#     capacity INTEGER NOT NULL,
#     external_id VARCHAR(100) NOT NULL,
#     has_kiosk BOOLEAN,
#     legacy_id VARCHAR(10),
#     region_id VARCHAR(10),
#     electric_bike_surcharge_waiver BOOLEAN,
#     eightd_station_services VARCHAR(20) ,
#     CONSTRAINT ustaion_id UNIQUE(station_id)
# )
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# Done.
# []

# %%
# %%sql
# CREATE TABLE stations(
#     id SERIAL PRIMARY KEY,
#     station_id VARCHAR(10) NOT NULL,
#     station_type VARCHAR(20) NOT NULL,
#     name VARCHAR(20) NOT NULL,
#     short_name VARCHAR(10) NOT NULL,
#     capacity INTEGER NOT NULL,
#     external_id VARCHAR(100) NOT NULL,
#     has_kiosk BOOLEAN,
#     legacy_id VARCHAR(10),
#     region_id VARCHAR(10),
#     electric_bike_surcharge_waiver BOOLEAN,
#     eightd_station_services VARCHAR ARRAY ,
#     CONSTRAINT ustaion_id UNIQUE(station_id)
# )

# %%
# %%sql
# select * from information_schema.columns where table_name='stations'
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 12 rows affected.
# [('itv002461_sms_db', 'public', 'stations', 'capacity', 6, None, 'NO', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'int4', None, None, None, None, '6', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'stations', 'has_kiosk', 8, None, 'YES', 'boolean', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'bool', None, None, None, None, '8', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'stations', 'electric_bike_surcharge_waiver', 11, None, 'YES', 'boolean', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'bool', None, None, None, None, '11', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'stations', 'id', 1, "nextval('stations_id_seq'::regclass)", 'NO', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'int4', None, None, None, None, '1', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'stations', 'short_name', 5, None, 'NO', 'character varying', 10, 40, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '5', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'stations', 'external_id', 7, None, 'NO', 'character varying', 100, 400, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '7', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'stations', 'legacy_id', 9, None, 'YES', 'character varying', 10, 40, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '9', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'stations', 'region_id', 10, None, 'YES', 'character varying', 10, 40, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '10', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'stations', 'eightd_station_services', 12, None, 'YES', 'character varying', 20, 80, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '12', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'stations', 'station_id', 2, None, 'NO', 'character varying', 10, 40, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '2', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'stations', 'station_type', 3, None, 'NO', 'character varying', 20, 80, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '3', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'stations', 'name', 4, None, 'NO', 'character varying', 20, 80, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '4', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES')]

# %% [markdown]
# ### Read data from JSON

# %%
import pandas as pd
import requests

url=' https://gbfs.citibikenyc.com/gbfs/en/station_information.json'
response=requests.get(url).json()
data=response['data']['stations']
df=pd.DataFrame(data)
#df=df.drop(['rental_methods','rental_uris','lat','lon','eightd_has_key_dispenser','eightd_station_services'],axis=1)
df
# Out:
#      station_type                           name  has_kiosk  capacity  \
# 0         classic               W 52 St & 11 Ave       True        55
# 1         classic       Franklin St & W Broadway       True        33
# 2         classic         St James Pl & Pearl St       True        27
# 3         classic  Atlantic Ave & Fort Greene Pl       True        62
# 4         classic                W 17 St & 8 Ave       True        50
# ...           ...                            ...        ...       ...
# 1618      classic      E 156 St & Courtlandt Ave       True        23
# 1619      classic               W 111 St & 5 Ave       True        24
# 1620      classic            South St & Broad St       True        31
# 1621      classic                 30 Ave & 12 St       True        33
# 1622      classic           Murray St\t& West St       True        41
#
#          rental_methods                           external_id        lat  \
# 0     [CREDITCARD, KEY]  66db237e-0aca-11e7-82f6-3863bb44ef7c  40.767272
# 1     [CREDITCARD, KEY]  66db269c-0aca-11e7-82f6-3863bb44ef7c  40.719116
# 2     [CREDITCARD, KEY]  66db277a-0aca-11e7-82f6-3863bb44ef7c  40.711174
# 3     [CREDITCARD, KEY]  66db281e-0aca-11e7-82f6-3863bb44ef7c  40.683826
# 4     [CREDITCARD, KEY]  66db28b5-0aca-11e7-82f6-3863bb44ef7c  40.741776
# ...                 ...                                   ...        ...
# 1618  [CREDITCARD, KEY]  4dcff9e7-7cb6-4d3d-ad67-c2e4c05933d3  40.821239
# 1619  [CREDITCARD, KEY]  0f51cb84-e386-44ac-947f-a969f7617d17  40.797521
# 1620  [CREDITCARD, KEY]  c00ef46d-fcde-48e2-afbd-0fb595fe3fa7  40.701889
# 1621  [CREDITCARD, KEY]  ce669a45-ad63-43bd-8aa1-4fc07237edaf  40.771749
# 1622  [CREDITCARD, KEY]  1286480d-5d6d-4a47-9fac-e156dba2b6fc  40.715030
#
#       eightd_has_key_dispenser  electric_bike_surcharge_waiver short_name  \
# 0                        False                           False    6926.01
# 1                        False                           False    5430.08
# 2                        False                           False    5167.06
# 3                        False                           False    4354.07
# 4                        False                           False    6148.02
# ...                        ...                             ...        ...
# 1618                     False                           False    7940.04
# 1619                     False                           False    7587.16
# 1620                     False                           False    4920.13
# 1621                     False                           False    7034.08
# 1622                     False                           False    5329.08
#
#      station_id legacy_id                                        rental_uris  \
# 0            72        72  {'android': 'https://bkn.lft.to/lastmile_qr_sc...
# 1            79        79  {'android': 'https://bkn.lft.to/lastmile_qr_sc...
# 2            82        82  {'android': 'https://bkn.lft.to/lastmile_qr_sc...
# 3            83        83  {'android': 'https://bkn.lft.to/lastmile_qr_sc...
# 4           116       116  {'android': 'https://bkn.lft.to/lastmile_qr_sc...
# ...         ...       ...                                                ...
# 1618       4745      4745  {'android': 'https://bkn.lft.to/lastmile_qr_sc...
# 1619       4746      4746  {'android': 'https://bkn.lft.to/lastmile_qr_sc...
# 1620       4748      4748  {'android': 'https://bkn.lft.to/lastmile_qr_sc...
# 1621       4753      4753  {'android': 'https://bkn.lft.to/lastmile_qr_sc...
# 1622       4754      4754  {'android': 'https://bkn.lft.to/lastmile_qr_sc...
#
#             lon eightd_station_services region_id
# 0    -73.993929                      []        71
# 1    -74.006667                      []        71
# 2    -74.000165                      []        71
# 3    -73.976323                      []        71
# 4    -74.001497                      []        71
# ...         ...                     ...       ...
# 1618 -73.917330                      []        71
# 1619 -73.948940                      []        71
# 1620 -74.010899                      []        71
# 1621 -73.931613                      []        71
# 1622 -74.012460                      []        71
#
# [1623 rows x 16 columns]

# %% [markdown]
# ### Connection

# %%
import psycopg2

def get_connection(host, port, database, user, password):
    connection = None
    try:
        connection = psycopg2.connect(
            host=host,
            port=port,
            database=database,
            user=user,
            password=password
        )
    except Exception as e:
        raise(e)
    
    return connection

# %%
host = 'pg.itversity.com'
port = '5433'
database = 'itv002461_sms_db'
user = 'itv002461_sms_user'
password = '7ji8g7gg8p8olbqbna5vz1tjyikaixco'

sms_connection = get_connection(
    host=host,
    port=port,
    database=database,
    user=user,
    password=password
)

# %%
# df.to_sql('stations',sms_connection,if_exists='append',index=False)

# %% [markdown]
# ### Insert Data into DataBase

# %%
cursor = sms_connection.cursor()

query = ("""
    INSERT INTO stations 
        (id,station_id,station_type,name ,short_name ,capacity ,external_id ,has_kiosk ,legacy_id ,region_id ,
        electric_bike_surcharge_waiver)
    VALUES 
        (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
""")
i=0
for index,data in df.iterrows():
    i+=1
    insert_data=[str(i),data.station_id,data.station_type,data.name,data.short_name,data.capacity,data.external_id,data.has_kiosk,
                data.legacy_id,data.region_id,data.electric_bike_surcharge_waiver]
    cursor.execute(query,insert_data)

sms_connection.commit()
print("Inserted")

# %%
# cursor = sms_connection.cursor()
# cursor.execute('select * from stations limit 10')
# for data in cursor:
#     print(data)

# %%
# %sql select * from stations limit 5
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 5 rows affected.
# [(1, '72', 'classic', '0', '6926.01', 55, '66db237e-0aca-11e7-82f6-3863bb44ef7c', True, '72', '71', False, None),
#  (2, '79', 'classic', '1', '5430.08', 33, '66db269c-0aca-11e7-82f6-3863bb44ef7c', True, '79', '71', False, None),
#  (3, '82', 'classic', '2', '5167.06', 27, '66db277a-0aca-11e7-82f6-3863bb44ef7c', True, '82', '71', False, None),
#  (4, '83', 'classic', '3', '4354.07', 62, '66db281e-0aca-11e7-82f6-3863bb44ef7c', True, '83', '71', False, None),
#  (5, '116', 'classic', '4', '6148.02', 50, '66db28b5-0aca-11e7-82f6-3863bb44ef7c', True, '116', '71', False, None)]

# %% [markdown]
# #### Distinct station_type

# %%
# %sql select distinct station_type from stations
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 1 rows affected.
# [('classic',)]

# %% [markdown]
# #### Get number of stations per region_id

# %%
# %%sql
#
# select region_id, count(1)
# from stations
# group by region_id
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 3 rows affected.
# [('311', 28), ('71', 1542), ('70', 53)]

# %% [markdown]
# #### Get top 10 stations by capacity.

# %%
# %%sql
#
# select station_id, capacity
# from stations
# group by station_id,capacity
# order by capacity desc
# limit 10
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 10 rows affected.
# [('445', 107),
#  ('293', 91),
#  ('248', 91),
#  ('4675', 87),
#  ('470', 84),
#  ('3687', 83),
#  ('501', 83),
#  ('386', 82),
#  ('426', 81),
#  ('4406', 80)]

# %% [markdown]
# #### Get number of stations where there are no kiosks

# %%
# %sql select count(1) from stations where has_kiosk=False
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 1 rows affected.
# [(3,)]

# %%
# %%sql
# create table station_rental_types(
#     station_id varchar(10) not null,
#     rental_type VARCHAR(50) CHECK (rental_type = 'KEY' or rental_type = 'CREDITCARD'),
#     station_rental_type_id serial primary key,
#     unique(station_id,rental_type)
# )
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# Done.
# []

# %%
# %%sql
#
# select * from information_schema.columns where table_name='station_rental_types'
# Out:
#  * postgresql://itv002461_sms_user:***@pg.itversity.com:5433/itv002461_sms_db
# 3 rows affected.
# [('itv002461_sms_db', 'public', 'station_rental_types', 'station_rental_type_id', 3, "nextval('station_rental_types_station_rental_type_id_seq'::regclass)", 'NO', 'integer', None, None, 32, 2, 0, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'int4', None, None, None, None, '3', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'station_rental_types', 'station_id', 1, None, 'NO', 'character varying', 10, 40, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '1', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES'),
#  ('itv002461_sms_db', 'public', 'station_rental_types', 'rental_type', 2, None, 'YES', 'character varying', 50, 200, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'itv002461_sms_db', 'pg_catalog', 'varchar', None, None, None, None, '2', 'NO', 'NO', None, None, None, None, None, 'NO', 'NEVER', None, 'YES')]

# %%
host = 'pg.itversity.com'
port = '5433'
database = 'itv002461_sms_db'
user = 'itv002461_sms_user'
password = '7ji8g7gg8p8olbqbna5vz1tjyikaixco'

sms_connection = get_connection(
    host=host,
    port=port,
    database=database,
    user=user,
    password=password
)

# %%
cursor = sms_connection.cursor()

query = ("""
    INSERT INTO station_rental_types 
        (station_id,rental_type)
    VALUES 
        (%s, %s)
""")

# %%
count=0
rental_method=[]
for i in range(0,(df.shape)[0]):
    if(len(df.rental_methods)==2):
        rental_method.extend([(df.station_id,df.rental_methods[0]),(df.station_id,df.rental_methods[1])])
    else:
        rental_method.append((df.station_id,df.rental_methods[0]))
df2=pd.DataFrame(rental_method)
df2
# Out:
#                                                       0                  1
# 0     0         72
# 1         79
# 2         82
# 3      ...  [CREDITCARD, KEY]
# 1     0         72
# 1         79
# 2         82
# 3      ...  [CREDITCARD, KEY]
# 2     0         72
# 1         79
# 2         82
# 3      ...  [CREDITCARD, KEY]
# 3     0         72
# 1         79
# 2         82
# 3      ...  [CREDITCARD, KEY]
# 4     0         72
# 1         79
# 2         82
# 3      ...  [CREDITCARD, KEY]
# ...                                                 ...                ...
# 1618  0         72
# 1         79
# 2         82
# 3      ...  [CREDITCARD, KEY]
# 1619  0         72
# 1         79
# 2         82
# 3      ...  [CREDITCARD, KEY]
# 1620  0         72
# 1         79
# 2         82
# 3      ...  [CREDITCARD, KEY]
# 1621  0         72
# 1         79
# 2         82
# 3      ...  [CREDITCARD, KEY]
# 1622  0         72
# 1         79
# 2         82
# 3      ...  [CREDITCARD, KEY]
#
# [1623 rows x 2 columns]

# %%
rental_method=map(lambda rental_type: [(df.station_id,rental_type[0]),(df.station_id,rental_type[1])] , list(df.rental_methods))
filter_data=list(rental_method)
for data in filter_data:
    if len(data)==2:
        print(data)
        break
# Out:
# [(0         72
# 1         79
# 2         82
# 3         83
# 4        116
#         ...
# 1618    4745
# 1619    4746
# 1620    4748
# 1621    4753
# 1622    4754
# Name: station_id, Length: 1623, dtype: object, 'CREDITCARD'), (0         72
# 1         79
# 2         82
# 3         83
# 4        116
#         ...
# 1618    4745
# 1619    4746
# 1620    4748
# 1621    4753
# 1622    4754
# Name: station_id, Length: 1623, dtype: object, 'KEY')]
