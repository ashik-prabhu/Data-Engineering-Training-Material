# %% [markdown]
# ## Exercises - Pandas Data Frames
#
# Here are some of the Exercises related to Pandas.
# * Create Pandas Data Frames using Schema
# * Get all the orders which belong to the month of 2013 August
# * Get all the orders which belong to the months of August, September and October in 2013.
# * Get count of orders by status for the month of 2014 January
# * Get all the records from orders where there are no corresponding records in order_items
# * Get all the customers who have not placed any orders
# * Get the revenue by status

# %% [markdown]
# ### Exercise 1 - Create Pandas Data Frames using Schema
#
# Create Pandas Data Frame for orders, order_items and customers. Make sure to use **schema/retail_db/retail.json** to get the column names.

# %%
import os
import json
import csv
import pandas as pd

def get_df(base_folder, data_set_name, schema_file):
    file_names = os.listdir(f'{base_folder}/{data_set_name}')
    retail_schemas = json.load(open(schema_file))
    columns = list(map(lambda col: col['column_name'], retail_schemas[data_set_name]))
    data = []
    for file_name in file_names:
        file_path = f'{base_folder}/{data_set_name}/{file_name}'
        raw_data = open(file_path)
        data += list(raw_data)
    return pd.DataFrame(map(lambda rec: rec.split(','), data), columns=columns)

# %%
orders = get_df('/data/retail_db', 'orders', 'schemas/retail_db/retail.json')

# %%
customers = get_df('/data/retail_db', 'customers', 'schemas/retail_db/retail.json')

# %%
order_items = get_df('/data/retail_db', 'order_items', 'schemas/retail_db/retail.json')
# order_items[:3]

# %%
# order_items.query('order_item_order_id == 2')

# %%
# order_items[order_items['order_item_order_id'] == 2]

# %%
order_items['order_item_order_id']
# Out:
# 0             1
# 1             2
# 2             2
# 3             2
# 4             4
#           ...
# 172193    68881
# 172194    68882
# 172195    68882
# 172196    68883
# 172197    68883
# Name: order_item_order_id, Length: 172198, dtype: object

# %%
order_items.order_item_order_id [:4]
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# Name: order_item_order_id, dtype: object

# %% [markdown]
# ### Get all the orders which belong to the month of 2013 August

# %%
orders.query('order_date.str.startswith("2013-08")', engine='python')
# Out:
#       order_id             order_date order_customer_id       order_status
# 1296      1297  2013-08-01 00:00:00.0             11607         COMPLETE\n
# 1297      1298  2013-08-01 00:00:00.0              5105           CLOSED\n
# 1298      1299  2013-08-01 00:00:00.0              7802         COMPLETE\n
# 1299      1300  2013-08-01 00:00:00.0               553  PENDING_PAYMENT\n
# 1300      1301  2013-08-01 00:00:00.0              1604  PENDING_PAYMENT\n
# ...        ...                    ...               ...                ...
# 68705    68706  2013-08-20 00:00:00.0               130         COMPLETE\n
# 68706    68707  2013-08-23 00:00:00.0             11730         COMPLETE\n
# 68707    68708  2013-08-26 00:00:00.0              8852          ON_HOLD\n
# 68708    68709  2013-08-30 00:00:00.0              4756         COMPLETE\n
# 68709    68710  2013-08-31 00:00:00.0              9685         COMPLETE\n
#
# [5680 rows x 4 columns]

# %% [markdown]
# [09:44] megha mishra
# orders[(orders.order_date.str.startswith('2013-08')) | (orders.order_date.str.startswith('2013-09')) | (orders.order_date.str.startswith('2013-10'))]
#
# ### Get all the orders which belong to the months of August, September and October in 2013.

# %%
orders[(orders.order_date.str.startswith('2013-08')) | 
       (orders.order_date.str.startswith('2013-09')) | 
       (orders.order_date.str.startswith('2013-10'))]
# Out:
#       order_id             order_date order_customer_id       order_status
# 1296      1297  2013-08-01 00:00:00.0             11607         COMPLETE\n
# 1297      1298  2013-08-01 00:00:00.0              5105           CLOSED\n
# 1298      1299  2013-08-01 00:00:00.0              7802         COMPLETE\n
# 1299      1300  2013-08-01 00:00:00.0               553  PENDING_PAYMENT\n
# 1300      1301  2013-08-01 00:00:00.0              1604  PENDING_PAYMENT\n
# ...        ...                    ...               ...                ...
# 68737    68738  2013-10-27 00:00:00.0              1100         COMPLETE\n
# 68738    68739  2013-10-28 00:00:00.0              2528          PENDING\n
# 68739    68740  2013-10-29 00:00:00.0             10691          ON_HOLD\n
# 68740    68741  2013-10-30 00:00:00.0              5974  PENDING_PAYMENT\n
# 68741    68742  2013-10-31 00:00:00.0               197         COMPLETE\n
#
# [16856 rows x 4 columns]

# %% [markdown]
# ### Get count of orders by status for the month of 2014 January

# %%
orders[orders['order_date'].str.slice(0, 7).str.replace('-', '').astype('int64') == 201401]['order_status'].count()
# Out:
# 5908

# %% [markdown]
# ### Get all the records from orders where there are no corresponding records in order_items

# %%
orders_joined = orders.set_index('order_id'). \
join(order_items.set_index('order_item_order_id'))
orders_joined[orders_joined['order_item_id'].isna()]
# Out:
#                   order_date order_customer_id       order_status  \
# 10015  2013-09-25 00:00:00.0              3112         COMPLETE\n
# 10016  2013-09-25 00:00:00.0              1214       PROCESSING\n
# 10022  2013-09-25 00:00:00.0              2697  PENDING_PAYMENT\n
# 10031  2013-09-25 00:00:00.0              9968         COMPLETE\n
# 10035  2013-09-25 00:00:00.0              2570  PENDING_PAYMENT\n
# ...                      ...               ...                ...
# 9978   2013-09-25 00:00:00.0              3100         CANCELED\n
# 9980   2013-09-25 00:00:00.0              8261  PENDING_PAYMENT\n
# 9982   2013-09-25 00:00:00.0              4860         COMPLETE\n
# 9994   2013-09-25 00:00:00.0              9585  PENDING_PAYMENT\n
# 9996   2013-09-25 00:00:00.0             11839          PENDING\n
#
#       order_item_id order_item_product_id order_item_quantity  \
# 10015           NaN                   NaN                 NaN
# 10016           NaN                   NaN                 NaN
# 10022           NaN                   NaN                 NaN
# 10031           NaN                   NaN                 NaN
# 10035           NaN                   NaN                 NaN
# ...             ...                   ...                 ...
# 9978            NaN                   NaN                 NaN
# 9980            NaN                   NaN                 NaN
# 9982            NaN                   NaN                 NaN
# 9994            NaN                   NaN                 NaN
# 9996            NaN                   NaN                 NaN
#
#       order_item_subtotal order_item_product_price
# 10015                 NaN                      NaN
# 10016                 NaN                      NaN
# 10022                 NaN                      NaN
# 10031                 NaN                      NaN
# 10035                 NaN                      NaN
# ...                   ...                      ...
# 9978                  NaN                      NaN
# 9980                  NaN                      NaN
# 9982                  NaN                      NaN
# 9994                  NaN                      NaN
# 9996                  NaN                      NaN
#
# [11452 rows x 8 columns]

# %% [markdown]
# ### Get all the customers who have not placed any orders

# %%
customer_order=customers.set_index('customer_id'). \
join(orders.set_index('order_customer_id'))
customer_order[customer_order['order_id'].isna()].reset_index().rename(columns={'index':'customer_id'})
# Out:
#    customer_id customer_fname customer_lname customer_email customer_password  \
# 0        10060           Mary           Shaw      XXXXXXXXX         XXXXXXXXX
# 1        10330           Mary          Smith      XXXXXXXXX         XXXXXXXXX
# 2        10439           Emma          Smith      XXXXXXXXX         XXXXXXXXX
# 3        10913           Mary       Williams      XXXXXXXXX         XXXXXXXXX
# 4        10958           Joan          Smith      XXXXXXXXX         XXXXXXXXX
# 5         1187        Dorothy        Vazquez      XXXXXXXXX         XXXXXXXXX
# 6        12175         Amanda          Smith      XXXXXXXXX         XXXXXXXXX
# 7        12190           Mary          Smith      XXXXXXXXX         XXXXXXXXX
# 8        12392           Alan           Wolf      XXXXXXXXX         XXXXXXXXX
# 9         1481          Grace          Smith      XXXXXXXXX         XXXXXXXXX
# 10        1808         Albert        Ellison      XXXXXXXXX         XXXXXXXXX
# 11        2073          Donna       Stephens      XXXXXXXXX         XXXXXXXXX
# 12        2096           Jose         Tanner      XXXXXXXXX         XXXXXXXXX
# 13         219           Mary        Harrell      XXXXXXXXX         XXXXXXXXX
# 14        2450          James          Smith      XXXXXXXXX         XXXXXXXXX
# 15         339           Mary         Greene      XXXXXXXXX         XXXXXXXXX
# 16        4555           Mary          Smith      XXXXXXXXX         XXXXXXXXX
# 17         469          Randy          Smith      XXXXXXXXX         XXXXXXXXX
# 18        4927        Carolyn          Green      XXXXXXXXX         XXXXXXXXX
# 19        6072        Stephen          Smith      XXXXXXXXX         XXXXXXXXX
# 20        6613         Ashley          Smith      XXXXXXXXX         XXXXXXXXX
# 21        7011          Kevin          Smith      XXXXXXXXX         XXXXXXXXX
# 22        7552           Carl          Smith      XXXXXXXXX         XXXXXXXXX
# 23        8243           Gary         Walker      XXXXXXXXX         XXXXXXXXX
# 24        8343           Mary         Bolton      XXXXXXXXX         XXXXXXXXX
# 25        8575           Mary        Mueller      XXXXXXXXX         XXXXXXXXX
# 26        8778           Mary          Smith      XXXXXXXXX         XXXXXXXXX
# 27        8882        Kenneth          Smith      XXXXXXXXX         XXXXXXXXX
# 28        9060        Matthew          Patel      XXXXXXXXX         XXXXXXXXX
# 29        9315           Mary          Lewis      XXXXXXXXX         XXXXXXXXX
#
#                  customer_street         customer_city customer_state  \
# 0     4645 Fallen Timber By-pass                Caguas             PR
# 1       3410 Lazy Shadow Pathway              Hamilton             OH
# 2       1465 Clear Elk Diversion                Caguas             PR
# 3        9113 Grand Hills Parade              San Jose             CA
# 4        8771 Middle Quail Heath           Los Angeles             CA
# 5            363 Green Goose Run               Danbury             CT
# 6   3729 Cinder Grove Concession             Tonawanda             NY
# 7       4462 Little Lagoon Route                 Tempe             AZ
# 8     6470 Fallen Barn Autoroute             Santa Ana             CA
# 9           2171 Clear Lake Isle                Caguas             PR
# 10             9795 Heather Wynd              Billings             MT
# 11             9792 Cozy Corners             Sunnyvale             CA
# 12      8976 Old Hickory Landing                 Bronx             NY
# 13   9016 Foggy Robin Expressway                Denver             CO
# 14       4063 Little Creek Court                Newark             DE
# 15               4271 Hazy Close            Long Beach             CA
# 16          5455 Red Lagoon Maze                Caguas             PR
# 17         252 Golden Goose Loop   South San Francisco             CA
# 18        7550 Sleepy View Court                Caguas             PR
# 19       849 Noble Apple Private                Malden             MA
# 20       9847 Dusty Horse Corner                Caguas             PR
# 21  1915 Thunder Hickory Freeway             Wyandotte             MI
# 22              9966 Cinder Loop                Howell             MI
# 23        2447 Stony Barn Street              New York             NY
# 24             7302 Sunny Valley                Caguas             PR
# 25     9714 Emerald Bear Lookout                Caguas             PR
# 26      4015 Tawny Rise Crescent                Caguas             PR
# 27           6754 Iron Leaf Line               Hickory             NC
# 28       7190 Silver Horse Glade             Henderson             NV
# 29       2993 Burning Dale Farms  North Richland Hills             TX
#
#    customer_zipcode order_id order_date order_status
# 0           00725\n      NaN        NaN          NaN
# 1           45013\n      NaN        NaN          NaN
# 2           00725\n      NaN        NaN          NaN
# 3           95123\n      NaN        NaN          NaN
# 4           90024\n      NaN        NaN          NaN
# 5           06810\n      NaN        NaN          NaN
# 6           14150\n      NaN        NaN          NaN
# 7           85283\n      NaN        NaN          NaN
# 8           92704\n      NaN        NaN          NaN
# 9           00725\n      NaN        NaN          NaN
# 10          59102\n      NaN        NaN          NaN
# 11          94087\n      NaN        NaN          NaN
# 12          10467\n      NaN        NaN          NaN
# 13          80219\n      NaN        NaN          NaN
# 14          19702\n      NaN        NaN          NaN
# 15          90805\n      NaN        NaN          NaN
# 16          00725\n      NaN        NaN          NaN
# 17          94080\n      NaN        NaN          NaN
# 18          00725\n      NaN        NaN          NaN
# 19          02148\n      NaN        NaN          NaN
# 20          00725\n      NaN        NaN          NaN
# 21          48192\n      NaN        NaN          NaN
# 22          48843\n      NaN        NaN          NaN
# 23          10128\n      NaN        NaN          NaN
# 24          00725\n      NaN        NaN          NaN
# 25          00725\n      NaN        NaN          NaN
# 26          00725\n      NaN        NaN          NaN
# 27          28601\n      NaN        NaN          NaN
# 28          89014\n      NaN        NaN          NaN
# 29          76180\n      NaN        NaN          NaN

# %%
#order_items[order_items['order_item_order_id']==2]
# order_items.query('order_item_order_id == 2')

# %% [markdown]
# ### Get the revenue by status

# %%
df_joined = orders.set_index('order_id').join(order_items.set_index('order_item_order_id'),how = 'inner')
order_item_subtotal_float = df_joined['order_item_subtotal'].astype(float)
df_joined['order_item_subtotal'] = order_item_subtotal_float
group_by_status = round(df_joined.groupby('order_status')['order_item_subtotal'].agg([sum]),2).rename(columns = {'sum':'Revenue'}).reset_index()
group_by_status
# Out:
#         order_status      Revenue
# 0         CANCELED\n    696030.99
# 1           CLOSED\n   3736048.79
# 2         COMPLETE\n  11276933.69
# 3          ON_HOLD\n   1864731.24
# 4   PAYMENT_REVIEW\n    357841.45
# 5          PENDING\n   3851881.28
# 6  PENDING_PAYMENT\n   7581671.05
# 7       PROCESSING\n   4190636.76
# 8  SUSPECTED_FRAUD\n    766844.68
